# %% [markdown]
# ### SVM(Support Vector Machine)
# ---
# - ML에서 오랫동안 연구되었고 성능이 좋은 모델
# - DL보다 성능이 좋은 경우도 있음

# %%
## 모듈 로딩 ------------------------------------
from sklearn.svm import SVC
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## [1] 데이터 준비
# ---

# %%
digits = load_digits()
print(digits.data.shape)

import matplotlib.pyplot as plt
plt.gray()
plt.matshow(digits.images[0])
plt.show()
# Out:
# (1797, 64)

# %%
digit = load_digits()

# %%
# data, target 분리
data = digit['data']
target = digit['target']

# %%
print(f'data : {data.shape}, target : {target.shape}')
# Out:
# data : (1797, 64), target : (1797,)

# %%
print(f'data[0] : {data[0]}')
# Out:
# data[0] : [ 0.  0.  5. 13.  9.  1.  0.  0.  0.  0. 13. 15. 10. 15.  5.  0.  0.  3.
#  15.  2.  0. 11.  8.  0.  0.  4. 12.  0.  0.  8.  8.  0.  0.  5.  8.  0.
#   0.  9.  8.  0.  0.  4. 11.  0.  1. 12.  7.  0.  0.  2. 14.  5. 10. 12.
#   0.  0.  0.  0.  6. 13. 10.  0.  0.  0.]

# %%
print(f'Target : {target[2]} - images[2] \n\n{digit["images"][2]}')
# Out:
# Target : 2 - images[2]
#
# [[ 0.  0.  0.  4. 15. 12.  0.  0.]
#  [ 0.  0.  3. 16. 15. 14.  0.  0.]
#  [ 0.  0.  8. 13.  8. 16.  0.  0.]
#  [ 0.  0.  1.  6. 15. 11.  0.  0.]
#  [ 0.  1.  8. 13. 15.  1.  0.  0.]
#  [ 0.  9. 16. 16.  5.  0.  0.  0.]
#  [ 0.  3. 13. 16. 16. 11.  5.  0.]
#  [ 0.  0.  0.  3. 11. 16.  9.  0.]]

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
fig, axs = plt.subplots(2, 5, figsize=(10, 4))
for i in range(2):
    for ii in range(5):
        plt.gray()
        axs[i][ii]=plt.matshow(digit['images'][1])

plt.show()

# %% [markdown]
# ## [2] 학습용 & 테스트용

# %%
train_input, test_input, train_target, test_target = train_test_split(
data, target, random_state=42)

# %% [markdown]
# ## [3] 모델 생성
# ---
# - 0 ~ 9 : 10개 분류
# - LR, SVC

# %%
# 모델 객체 생성
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# 학습 ==> 트레이닝 데이터 사용
# fit()메서드 => 2차원 형태 데이터
model.fit(train_input, train_target)
# Out:
# LinearRegression()

# %%
model.score(train_input, train_target)
# Out:
# 0.6011212591721744

# %%
model.score(test_input, test_target)
# Out:
# 0.5730446703017518

# %%
print('w: ', model.coef_, 'b: ', model.intercept_)
# Out:
# w:  [-2.16307427e-15  4.31667079e-02 -2.81421606e-03 -5.69172781e-02
#   6.54505140e-02 -1.07294178e-02 -4.14837139e-02  1.85154686e-02
#   1.00951449e+00 -3.03014210e-02  9.62130946e-02  4.60609775e-02
#  -6.45825420e-02 -7.24252922e-02  9.22586659e-02  1.75847262e-01
#  -6.98483873e-01  8.04228619e-03  7.70224550e-02 -2.37389719e-02
#  -7.56314486e-02  4.16484381e-02 -5.11602948e-02 -2.12004629e-01
#  -7.87921400e-01 -1.61871026e-01  3.17423384e-02  7.35276603e-02
#   8.38433981e-02  8.47729409e-02 -7.80588870e-03 -3.13637697e+00
#  -1.11022302e-15 -1.57956238e-01 -1.50416762e-02  1.34210489e-01
#  -5.49598281e-02  3.19477613e-02 -2.06664900e-02  1.83186799e-15
#   6.87849170e-02  1.03008303e-01 -2.15176697e-02 -2.94208155e-03
#   1.21985497e-01  6.23035192e-02  2.56817481e-02  1.06398611e-01
#   6.02943076e-01  3.02478230e-02  6.83306599e-03 -7.38178777e-02
#  -2.20324683e-01 -4.08114320e-02  9.47299563e-02 -2.03600506e-01
#  -1.42807061e+00 -1.38440943e-01  1.70143240e-02 -4.33844350e-02
#  -1.50926737e-02 -6.78243752e-02 -1.26822166e-02 -1.90299151e-02] b:  3.744869806168304

# %% [markdown]
# - 모델 객체 생성
# - 모델.fit()
# - 모델.score()
# - <- 성능 튜닝 (하이퍼파라미터)
# - 모델.predict([[]])
