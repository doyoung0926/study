# %%
# 모듈 로딩 --------------------------------------------------------
import pandas as pd

# 파일 관련 변수들 --------------------------------------------------
DIR='../Data/'
FILE=DIR+'country_timeseries.csv'

FILE
# Out:
# '../Data/country_timeseries.csv'

# %%
# (1) CSV => DataFrame 로딩
ebolaDF = pd.read_csv(FILE)   # nrows 원하는 행까지만 가져올 수 있음
ebolaDF
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
# (2) 데이터 확인
ebolaDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    object
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
ebolaDF
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
# (3) 전처리 -----------------------------------------------------------
# (3-1) NaN 데이터 처리 => 
ebolaDF.dropna(how='all')

# (3-2) Data Type 정리 =>
result=pd.to_datetime(ebolaDF['Date'])
result.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 122 entries, 0 to 121
# Series name: Date
# Non-Null Count  Dtype
# --------------  -----
# 122 non-null    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 1.1 KB

# %%
# (4) 데이터 가공 -------------------------------------------------
# Ebola 바이러스 발병 후 며칠(Day)이 지났는지에 대한 컬럼 추가
from datetime import datetime

current=datetime.today()
print(f'current => {current}')
# Out:
# current => 2022-07-08 08:28:33.421549

# %%
ebolaDF['Date'].dtype
# Out:
# dtype('O')

# %%
ebolaDF['Date']=pd.to_datetime(ebolaDF['Date'])
ebolaDF['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
ebolaDF['Date']=ebolaDF['Date'].astype('datetime64')   # ??
ebolaDF['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
d_days=current - ebolaDF['Date']

# %%
d_days[0].days, d_days[0].delta, d_days[0].seconds     # delta 는 나노세컨드로 나옴
# Out:
# (2741, 236852913421549000, 30513)

# %%
ebolaDF['D-Day']=d_days

# %%
ebolaDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    datetime64[ns]
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
ebolaDF.index
# Out:
# RangeIndex(start=0, stop=122, step=1)

# %%
# ebolaDF.index=[]
ebolaDF.set_index('Date', inplace=True)

# %%
ebolaDF
# Out:
#             Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 2015-01-05  289        2776.0            NaN            10030.0
# 2015-01-04  288        2775.0            NaN             9780.0
# 2015-01-03  287        2769.0         8166.0             9722.0
# 2015-01-02  286           NaN         8157.0                NaN
# 2014-12-31  284        2730.0         8115.0             9633.0
# ...         ...           ...            ...                ...
# 2014-03-27    5         103.0            8.0                6.0
# 2014-03-26    4          86.0            NaN                NaN
# 2014-03-25    3          86.0            NaN                NaN
# 2014-03-24    2          86.0            NaN                NaN
# 2014-03-22    0          49.0            NaN                NaN
#
#             Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# Date
# 2015-01-05            NaN            NaN                 NaN          NaN
# ...

# %%
# day=[]
# for i in ebolaDF.index:
#     day.append((current-ebolaDF.loc[i]['Date']).days)
#      
# day
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 day=[]
# ----> 2 for i in ebolaDF.index:
#       3     day.append((current-ebolaDF.loc[i]['Date']).days)
#       5 day
#
# NameError: name 'ebolaDF' is not defined

# %%
# ebolaDF['Day']=day
# ebolaDF
