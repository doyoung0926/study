# %%
'''
Word Cloud 사용하기
- https://knowable.tistory.com/5
'''
from wordcloud import WordCloud
from konlpy.tag import Okt
from collections import Counter
import matplotlib.pyplot as plt
import platform
# open으로 txt파일을 열고 read()를 이용하여 읽는다.
text = open('test.txt',encoding='utf-8').read()
okt = Okt() # Open Korean Text 객체 생성

# okt함수를 통해 읽어들인 내용의 형태소를 분석한다.
sentences_tag = []
sentences_tag = okt.pos(text)

noun_adj_list = []
# tag가 명사이거나 형용사인 단어들만 noun_adj_list에 넣어준다.
for word, tag in sentences_tag:
    if tag in ['Noun' , 'Adjective']:
        noun_adj_list.append(word)

print(noun_adj_list)
# 가장 많이 나온 단어부터 40개를 저장한다.
counts = Counter(noun_adj_list)
tags = counts.most_common(40)
print(tags)

# WordCloud를 생성한다.
# 한글을 분석하기위해 font를 한글로 지정해주어야 된다. macOS는 .otf , window는 .ttf 파일의 위치를
# 지정해준다. (ex. '/Font/GodoM.otf')
if platform.system() == 'Windows':
    path = r'c:\Windows\Fonts\malgun.ttf'
elif platform.system() == 'Darwin': # Mac OS
    path = r'/System/Library/Fonts/AppleGothic'
else:
    path = r'/usr/share/fonts/truetype/name/NanumMyeongjo.ttf'

wc = WordCloud(font_path=path, background_color="white", max_font_size=60)
cloud = wc.generate_from_frequencies(dict(tags))

# 생성된 WordCloud를 test.jpg로 보낸다.
#cloud.to_file('test.jpg')

plt.figure(figsize=(10, 8))
plt.axis('off')
plt.imshow(cloud)
plt.show()
# Out:
# ['우리나라', '경우', '보통', '여', '년', '단위', '구분', '대표', '세대', '중반', '산업화', '세대', '중반', '초반', '베이비부머', '세대', '세대', '세대', '중후', '반', '세대', '일명', '밀레니엄', '세대', '그', '이후', '세대', '있다', '이중', '우리나라', '청년', '세대', '세대', '수', '있다', '같은', '듯', '다른', '세대', '이', '무엇', '세대', '시대', '반영', '세대', '임', '먼저', '세대', '사이', '세대', '용어', '이', '용어', '캐나다', '작가', '더글라스', '커플', '랜드', '소설', '세대', '유래', '당시', '주목', '이', '소설', '기성세대', '다르지만', '정의', '힘든', '젊은', '세대', '칭', '마케팅', '기업', '선택', '말', '마땅하게', '정의', '용어', '없다', '뜻', '사용', '적절했기', '때문', '삐삐', '통한', '연락', '카세트', '테이프', '일종', '워크맨', '이', '세대', '경제', '풍요', '동시', '를', '세대', '체적', '시사', '경제', '쪽', '관심', '많은', '것', '특징', '당시', '경제', '풍요', '가운데', '새로운', '문화', '개인주의', '남', '차별', '화하는', '개성', '중시', '세대', '문화', '대표', '예', '거기', '컬러', '대중화', '대중문화', '성장하기', '시작', '당시', '선풍', '인기', '서태지', '아이', '은', '개성', '넘치는', '이미지', '세대', '열렬한', '지지', '이외', '홍콩영화', '다문화', '시대', '세대', '주름', '가장', '진보', '세대', '명칭', '현재', '세대', '기성세대', '역사상', '가장', '젊은', '타이틀', '토대', '세대', '특징', '간직', '소비', '트렌드', '주도하는', '세대', '자리매', '세대', '세대', '말로', '여기', '매사', '긍정', '참여', '점', '어떤', '일', '대답', '세대', '뜻', '약자', '이', '세대', '스마트폰', '를', '주로', '사용', '인스타그램', '등', '로', '소통', '욜', '족', '워', '라벨', '족', '등', '다양하게', '세대', '달리', '오프라인', '아닌', '온라인', '시대', '아날로그', '디지털', '공유', '밀레니엄', '세대', '불리', '기도', '이', '세대', '시절', '보', '시절', '향수', '자극', '것', '반응', '대표', '수원', '행리', '등', '레트로', '풍', '골목', '공유', '점', '특징', '또', '각종', '디지털', '기기', '발전', '몸소', '세대', '사회', '미', '버디버디', '싸이월드', '등', '그리워하는', '경향', '있다', '이', '세대', '가장', '특징', '지금', '이', '순간', '의', '행복', '위', '투자', '걸', '점', '이', '때문', '욜', '비', '가격', '대비', '마음', '만족', '추구', '워', '라벨', '등', '많은', '신조어', '탄생', '기도', '이러한', '면', '외', '연애', '결혼', '출산', '포기', '포', '세대', '나', '여러', '가지', '포기', '포', '세대', '어', '두운', '면도', '동시', '존재', '세대', '기도', '세대', '경우', '사이', '세대', '뜻', '세대', '다음', '의미', '세대', '컬', '며', '사물', '인터넷', '시대', '각종', '를', '사용', '다양성', '중시', '세대', '수', '있다', '세대', '달리', '처음', '온라인', '주요', '무대', '활동', '세대', '인터넷', '친숙하며', '컴퓨터', '스마트폰', '익숙하고', '텍스트', '이미지', '동영상', '콘텐츠', '선호', '편이', '방증', '듯', '세대', '가시', '유튜브', '감상', '제일', '유튜브', '통해', '검색', '등', '더', '생생하게', '정보', '선호', '세대', '를', '감상', '자라', '온', '것', '다른', '모습', '또한', '세대', '로부터', '자유로운', '가치관', '이전', '세대', '다양성', '중시', '편이', '일', '자체', '의미', '를', '더', '중요하게', '생각', '일과', '삶', '균형', '중시', '등', '특징', '대화', '비방', '같은', '듯', '다른', '대별', '트렌드', '이', '세대', '각자', '선호', '대화방', '다르다', '설문조사', '결과', '의하면', '세대', '음성', '통화', '세대', '세대', '모바일', '메신저', '선호', '답', '세대', '모바일', '메신저', '가장', '선호', '반면', '음성', '통화', '싫은', '이유', '대해', '세대', '다른', '세대', '말', '때', '침묵', '싫어서', '상대방', '말', '즉시', '대답', '통화', '동안', '다른', '일', '수', '없어서', '음성', '통화', '피', '응답', '많았다', '모바일', '메신저', '가장', '선호', '세대', '타', '세대', '달리', '온라인', '친구', '만들기', '적극', '때', '를', '접', '세대', '특징', '오프라인', '대인', '관계', '시간', '부족한', '학생', '모바일', '메신저', '대인', '관계', '형성', '자신', '표현', '수단', '사용', '적절하기', '때문', '각', '대별', '선호', '상품', '상이', '온라인', '쇼핑몰', '해', '기준', '전', '대비', '연령', '대별', '판매', '증감', '률', '비교', '분석', '결과', '세대', '기기', '및', '각종', '취미', '용품', '세대', '뉴트로', '추구', '성향', '뚜렷', '우선', '세대', '소비', '주', '근무', '제로', '가시', '늘', '자기계발', '취미', '생활', '대한', '관심', '변화', '이로', '인해', '나이', '초월', '개인', '취향', '제품', '선택', '자유롭게', '소비', '트렌드', '확대', '가장', '눈', '점', '작동', '정도', '지식', '요하', '디지털', '기기', '대한', '수요', '전', '대비', '급증', '점', '구체', '노트북', '웨어', '러블', '디바이스', '증가', '헬리', '캠', '드론', '무려', '배', '훌쩍', '신장', '세', '최근', '젊은', '층', '필수품', '자리', '잡고', '있는', '블루투스', '이어폰', '구매', '세대', '역시', '나', '급증', '취미', '생활', '젊어졌다', '같은', '기간', '개인', '나', '유튜브', '등', '콘텐츠', '제작', '필요한', '영상', '촬영', '용품', '량', '게임', '용품', '체력', '민첩함을', '요하', '스포츠', '연령', '경계', '서핑보드', '중장', '년층', '전', '대비', '전동', '킥', '보드', '자전거', '각각', '증가', '세대', '경우', '복고', '레트로', '를', '선호', '경향', '뚜렷하다', '실제', '레트로', '취미', '활동', '대표', '격인', '화폐', '주화', '우표', '수집', '용품', '경우', '판매량', '전', '대비', '증가', '것', '집계', '턴테이블', '오디오', '라디오', '수요', '덩달아', '증가', '또한', '우리', '전통', '복인', '한복', '일상생활', '젊은', '층', '패션', '캐', '주얼', '한복', '수요', '같은', '기간', '한복', '모습', '등', ...
# [('세대', 89), ('소비', 17), ('등', 16), ('이', 14), ('유튜브', 14), ('것', 13), ('명', 12), ('있다', 11), ('수', 11), ('를', 10), ('선호', 10), ('더', 9), ('자신', 9), ('영향', 9), ('크리에이터', 9), ('트렌드', 8), ('점', 8), ('있는', 8), ('중', 8), ('다른', 7), ('특징', 7), ('문화', 7), ('가장', 7), ('취미', 7), ('콘셉트', 7), ('중시', 6), ('현재', 6), ('달리', 6), ('통해', 6), ('브랜드', 6), ('대표', 5), ('같은', 5), ('젊은', 5), ('온라인', 5), ('대비', 5), ('만족', 5), ('편이', 5), ('제품', 5), ('플렉스', 5), ('경우', 4)]

# %%
'''
Naver 뉴스 워드 클라우드
- https://myjamong.tistory.com/48
- https://everyday-tech.tistory.com/entry/쉽게-따라하는-네이버-뉴스-크롤링python-2탄

'''

from bs4 import BeautifulSoup
import requests
from konlpy.tag import Okt
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import time
import re
import platform

def get_titles(start_num, end_num, search_word, title_list):
    # start_num ~ end_num까지 크롤링
    while 1:
        if start_num > end_num:
            break

        url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query={}&start={}'.format(
                search_word, start_num)

        req = requests.get(url)
        time.sleep(1)

        if req.ok: # 정상적인 request 확인
            soup = BeautifulSoup(req.text, 'html.parser')

            # 뉴스제목 뽑아오기
            list_news = soup.find('ul', {'class' : 'list_news'})
            #li_list = list_news.find_all('li', {'id': re.compile('sp_nws.*')})
            li_bxs = list_news.find_all('li', {'class': 'bx'})
            for li_bx in li_bxs:
                news_title = li_bx.find('a', {'class':'news_tit'})
                title_list.append(news_title['title'])
        start_num += 10
    print(title_list)


def make_wordcloud(word_count, title_list):
    okt = Okt()

    sentences_tag = []
    # 형태소 분석하여 리스트에 넣기
    for sentence in title_list:
        morph = okt.pos(sentence)
        sentences_tag.append(morph)
        print(morph)
        print('-' * 30)

    print(sentences_tag)
    print('\n' * 3)

    noun_adj_list = []
    # 명사와 형용사만 구분하여 이스트에 넣기
    for sentence1 in sentences_tag:
        for word, tag in sentence1:
            if tag in ['Noun', 'Adjective']:
                noun_adj_list.append(word)

    # 형태소별 count
    counts = Counter(noun_adj_list)
    tags = counts.most_common(word_count)
    print(tags)

    # wordCloud생성
    # 한글깨지는 문제 해결하기위해 font_path 지정
    if platform.system() == 'Windows':
        path = r'c:\Windows\Fonts\malgun.ttf'
    elif platform.system() == 'Darwin':  # Mac OS
        path = r'/System/Library/Fonts/AppleGothic'
    else:
        path = r'/usr/share/fonts/truetype/name/NanumMyeongjo.ttf'

    wc = WordCloud(font_path=path, background_color='white', width=800, height=600)
    print(dict(tags))
    cloud = wc.generate_from_frequencies(dict(tags))
    plt.figure(figsize=(10, 8))
    plt.axis('off')
    plt.imshow(cloud)
    plt.show()


if __name__ == '__main__':
    search_word = "빅데이터"  # 검색어 지정
    title_list = []
    # 1~200번게시글 까지 크롤링
    get_titles(1, 20, search_word, title_list)
    # 단어 30개까지 wordcloud로 출력
    make_wordcloud(20, title_list)
# Out:
# ['CJ의 혁신…빅데이터 이용했더니 택배상자 크기가 10% 줄었다', '총상금 1100만원, ‘빅데이터로 한강 수위 예측하라’', '[필수 노동 실태보고서]③ 빅데이터로 추적한 필수 노동자…분석 의미는?', '도로교통공단, 빅데이터 플랫폼 구축 위한 표준화 사업 착수', "CJ '빅데이터 패키징', 배송상자 크기 줄여", '서울보증보험, 보증보험 브랜드평판 7월 빅데이터 분석 톱', '“금융 빅데이터 활용해 소상공인 대출 지원”', '"112억 경우의 수 조합"…CJ대한통운 빅데이터로 택배박스 최적화', '골프장 브랜드평판 7월 빅데이터 분석결과', 'NICE지니데이타, 빅데이터 기반 지역상권 활성화 협력', '"112억 경우의 수 조합"…CJ대한통운 빅데이터로 택배박스 최적화', '코웨이, 가정용품 상장기업 브랜드평판 7월 빅데이터 분석 1위 기록', "쑥쑥 크는 빅테크 '경고등'에...SKT-하나금융, 4300억짜리 혈맹 맺다", 'SKT-하나금융 MOU…통신+금융지주 ‘짝짓기’, 빅블러시대 앞당기나', 'CJ대한통운, 빅데이터로 배송박스 크기 10% 줄여', '대전시, 공직자 대상 데이터 역량 강화교육', '교통연구원, 부동산 분야 빅데이터 플랫폼·센터 구축', "플랜투비즈니스컨설팅, 빅데이터 통합 솔루션 'e∙Mapp' 출시", '‘차클’ 혼자·장수·무인… 빅데이터 전문가가 분석한 우리 사회 키워드', '빅이벤트 앞둔 미 증시 첫 거래일 선물 하락 출발']
# [('CJ', 'Alpha'), ('의', 'Noun'), ('혁신', 'Noun'), ('…', 'Punctuation'), ('빅데이터', 'Noun'), ('이용', 'Noun'), ('했더니', 'Verb'), ('택배', 'Noun'), ('상자', 'Noun'), ('크기', 'Noun'), ('가', 'Josa'), ('10%', 'Number'), ('줄었다', 'Verb')]
# ------------------------------
# [('총', 'Modifier'), ('상금', 'Noun'), ('1100만원', 'Number'), (',', 'Punctuation'), ('‘', 'Foreign'), ('빅데이터', 'Noun'), ('로', 'Josa'), ('한강', 'Noun'), ('수위', 'Noun'), ('예측', 'Noun'), ('하', 'Suffix'), ('라', 'Josa'), ('’', 'Punctuation')]
# ------------------------------
# [('[', 'Punctuation'), ('필수', 'Noun'), ('노동', 'Noun'), ('실태', 'Noun'), ('보고서', 'Noun'), (']', 'Punctuation'), ('③', 'Foreign'), ('빅데이터', 'Noun'), ('로', 'Josa'), ('추적', 'Noun'), ('한', 'Josa'), ('필수', 'Noun'), ('노동자', 'Noun'), ('…', 'Punctuation'), ('분석', 'Noun'), ('의미', 'Noun'), ('는', 'Josa'), ('?', 'Punctuation')]
# ------------------------------
# [('도로', 'Noun'), ('교통', 'Noun'), ('공단', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('플랫폼', 'Noun'), ('구축', 'Noun'), ('위', 'Noun'), ('한', 'Josa'), ('표준화', 'Noun'), ('사업', 'Noun'), ('착수', 'Noun')]
# ------------------------------
# [('CJ', 'Alpha'), ("'", 'Punctuation'), ('빅데이터', 'Noun'), ('패키징', 'Noun'), ("',", 'Punctuation'), ('배송', 'Noun'), ('상자', 'Noun'), ('크기', 'Noun'), ('줄여', 'Verb')]
# ------------------------------
# [('서울', 'Noun'), ('보증', 'Noun'), ('보험', 'Noun'), (',', 'Punctuation'), ('보증', 'Noun'), ('보험', 'Noun'), ('브랜드', 'Noun'), ('평판', 'Noun'), ('7월', 'Number'), ('빅데이터', 'Noun'), ('분석', 'Noun'), ('톱', 'Noun')]
# ------------------------------
# [('“', 'Foreign'), ('금융', 'Noun'), ('빅데이터', 'Noun'), ('활용', 'Noun'), ('해', 'Verb'), ('소상', 'Noun'), ('공인', 'Noun'), ('대출', 'Noun'), ('지원', 'Noun'), ('”', 'Foreign')]
# ------------------------------
# [('"', 'Punctuation'), ('112억', 'Number'), ('경우', 'Noun'), ('의', 'Josa'), ('수', 'Noun'), ('조합', 'Noun'), ('"…', 'Punctuation'), ('CJ', 'Alpha'), ('대', 'Modifier'), ('한', 'Modifier'), ('통운', 'Noun'), ('빅데이터', 'Noun'), ('로', 'Josa'), ('택배', 'Noun'), ('박스', 'Noun'), ('최적화', 'Noun')]
# ------------------------------
# [('골프장', 'Noun'), ('브랜드', 'Noun'), ('평판', 'Noun'), ('7월', 'Number'), ('빅데이터', 'Noun'), ('분석', 'Noun'), ('결과', 'Noun')]
# ------------------------------
# [('NICE', 'Alpha'), ('지니', 'Noun'), ('데이타', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('기반', 'Noun'), ('지역', 'Noun'), ('상권', 'Noun'), ('활성화', 'Noun'), ('협력', 'Noun')]
# ------------------------------
# [('"', 'Punctuation'), ('112억', 'Number'), ('경우', 'Noun'), ('의', 'Josa'), ('수', 'Noun'), ('조합', 'Noun'), ('"…', 'Punctuation'), ('CJ', 'Alpha'), ('대', 'Modifier'), ('한', 'Modifier'), ('통운', 'Noun'), ('빅데이터', 'Noun'), ('로', 'Josa'), ('택배', 'Noun'), ('박스', 'Noun'), ('최적화', 'Noun')]
# ------------------------------
# [('코웨이', 'Noun'), (',', 'Punctuation'), ('가정', 'Noun'), ('용품', 'Noun'), ('상장', 'Noun'), ('기업', 'Noun'), ('브랜드', 'Noun'), ('평판', 'Noun'), ('7월', 'Number'), ('빅데이터', 'Noun'), ('분석', 'Noun'), ('1', 'Number'), ('위', 'Noun'), ('기록', 'Noun')]
# ------------------------------
# [('쑥쑥', 'Adverb'), ('크는', 'Verb'), ('빅', 'Noun'), ('테크', 'Noun'), ("'", 'Punctuation'), ('경', 'Modifier'), ('고등', 'Noun'), ("'", 'Punctuation'), ('에', 'Josa'), ('...', 'Punctuation'), ('SKT', 'Alpha'), ('-', 'Punctuation'), ('하나', 'Noun'), ('금융', 'Noun'), (',', 'Punctuation'), ('4300억', 'Number'), ('짜리', 'Foreign'), ('혈맹', 'Noun'), ('맺다', 'Verb')]
# ------------------------------
# [('SKT', 'Alpha'), ('-', 'Punctuation'), ('하나', 'Noun'), ('금융', 'Noun'), ('MOU', 'Alpha'), ('…', 'Punctuation'), ('통신', 'Noun'), ('+', 'Punctuation'), ('금융', 'Noun'), ('지주', 'Noun'), ('‘', 'Foreign'), ('짝짓기', 'Noun'), ('’,', 'Punctuation'), ('빅', 'Noun'), ('블러시', 'Noun'), ('대', 'Suffix'), ('앞당기나', 'Verb')]
# ------------------------------
# [('CJ', 'Alpha'), ('대', 'Modifier'), ('한', 'Modifier'), ('통운', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('로', 'Josa'), ('배송', 'Noun'), ('박스', 'Noun'), ('크기', 'Noun'), ('10%', 'Number'), ('줄여', 'Verb')]
# ------------------------------
# [('대', 'Modifier'), ('전시', 'Noun'), (',', 'Punctuation'), ('공직자', 'Noun'), ('대상', 'Noun'), ('데이터', 'Noun'), ('역량', 'Noun'), ('강화', 'Noun'), ('교육', 'Noun')]
# ------------------------------
# [('교통', 'Noun'), ('연구원', 'Noun'), (',', 'Punctuation'), ('부동산', 'Noun'), ('분야', 'Noun'), ('빅데이터', 'Noun'), ('플랫폼', 'Noun'), ('·', 'Punctuation'), ('센터', 'Noun'), ('구축', 'Noun')]
# ------------------------------
# [('플랜', 'Noun'), ('투', 'Noun'), ('비즈니스', 'Noun'), ('컨설팅', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('통합', 'Noun'), ('솔루션', 'Noun'), ("'", 'Punctuation'), ('e', 'Alpha'), ('∙', 'Foreign'), ('Mapp', 'Alpha'), ("'", 'Punctuation'), ('출시', 'Noun')]
# ------------------------------
# [('‘', 'Foreign'), ('차', 'Noun'), ('클', 'Verb'), ('’', 'Punctuation'), ('혼자', 'Noun'), ('·', 'Punctuation'), ('장수', 'Noun'), ('·', 'Punctuation'), ('무인', 'Noun'), ('…', 'Punctuation'), ('빅데이터', 'Noun'), ('전문가', 'Noun'), ('가', 'Josa'), ('분석', 'Noun'), ('한', 'Josa'), ('우리', 'Noun'), ('사회', 'Noun'), ('키', 'Noun'), ('워드', 'Noun')]
# ------------------------------
# [('빅', 'Noun'), ('이벤트', 'Noun'), ('앞둔', 'Verb'), ('미', 'Adjective'), ('증시', 'Noun'), ('첫', 'Noun'), ('거래', 'Noun'), ('일', 'Noun'), ('선물', 'Noun'), ('하락', 'Noun'), ('출발', 'Noun')]
# ------------------------------
# [[('CJ', 'Alpha'), ('의', 'Noun'), ('혁신', 'Noun'), ('…', 'Punctuation'), ('빅데이터', 'Noun'), ('이용', 'Noun'), ('했더니', 'Verb'), ('택배', 'Noun'), ('상자', 'Noun'), ('크기', 'Noun'), ('가', 'Josa'), ('10%', 'Number'), ('줄었다', 'Verb')], [('총', 'Modifier'), ('상금', 'Noun'), ('1100만원', 'Number'), (',', 'Punctuation'), ('‘', 'Foreign'), ('빅데이터', 'Noun'), ('로', 'Josa'), ('한강', 'Noun'), ('수위', 'Noun'), ('예측', 'Noun'), ('하', 'Suffix'), ('라', 'Josa'), ('’', 'Punctuation')], [('[', 'Punctuation'), ('필수', 'Noun'), ('노동', 'Noun'), ('실태', 'Noun'), ('보고서', 'Noun'), (']', 'Punctuation'), ('③', 'Foreign'), ('빅데이터', 'Noun'), ('로', 'Josa'), ('추적', 'Noun'), ('한', 'Josa'), ('필수', 'Noun'), ('노동자', 'Noun'), ('…', 'Punctuation'), ('분석', 'Noun'), ('의미', 'Noun'), ('는', 'Josa'), ('?', 'Punctuation')], [('도로', 'Noun'), ('교통', 'Noun'), ('공단', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('플랫폼', 'Noun'), ('구축', 'Noun'), ('위', 'Noun'), ('한', 'Josa'), ('표준화', 'Noun'), ('사업', 'Noun'), ('착수', 'Noun')], [('CJ', 'Alpha'), ("'", 'Punctuation'), ('빅데이터', 'Noun'), ('패키징', 'Noun'), ("',", 'Punctuation'), ('배송', 'Noun'), ('상자', 'Noun'), ('크기', 'Noun'), ('줄여', 'Verb')], [('서울', 'Noun'), ('보증', 'Noun'), ('보험', 'Noun'), (',', 'Punctuation'), ('보증', 'Noun'), ('보험', 'Noun'), ('브랜드', 'Noun'), ('평판', 'Noun'), ('7월', 'Number'), ('빅데이터', 'Noun'), ('분석', 'Noun'), ('톱', 'Noun')], [('“', 'Foreign'), ('금융', 'Noun'), ('빅데이터', 'Noun'), ('활용', 'Noun'), ('해', 'Verb'), ('소상', 'Noun'), ('공인', 'Noun'), ('대출', 'Noun'), ('지원', 'Noun'), ('”', 'Foreign')], [('"', 'Punctuation'), ('112억', 'Number'), ('경우', 'Noun'), ('의', 'Josa'), ('수', 'Noun'), ('조합', 'Noun'), ('"…', 'Punctuation'), ('CJ', 'Alpha'), ('대', 'Modifier'), ('한', 'Modifier'), ('통운', 'Noun'), ('빅데이터', 'Noun'), ('로', 'Josa'), ('택배', 'Noun'), ('박스', 'Noun'), ('최적화', 'Noun')], [('골프장', 'Noun'), ('브랜드', 'Noun'), ('평판', 'Noun'), ('7월', 'Number'), ('빅데이터', 'Noun'), ('분석', 'Noun'), ('결과', 'Noun')], [('NICE', 'Alpha'), ('지니', 'Noun'), ('데이타', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('기반', 'Noun'), ('지역', 'Noun'), ('상권', 'Noun'), ('활성화', 'Noun'), ('협력', 'Noun')], [('"', 'Punctuation'), ('112억', 'Number'), ('경우', 'Noun'), ('의', 'Josa'), ('수', 'Noun'), ('조합', 'Noun'), ('"…', 'Punctuation'), ('CJ', 'Alpha'), ('대', 'Modifier'), ('한', 'Modifier'), ('통운', 'Noun'), ('빅데이터', 'Noun'), ('로', 'Josa'), ('택배', 'Noun'), ('박스', 'Noun'), ('최적화', 'Noun')], [('코웨이', 'Noun'), (',', 'Punctuation'), ('가정', 'Noun'), ('용품', 'Noun'), ('상장', 'Noun'), ('기업', 'Noun'), ('브랜드', 'Noun'), ('평판', 'Noun'), ('7월', 'Number'), ('빅데이터', 'Noun'), ('분석', 'Noun'), ('1', 'Number'), ('위', 'Noun'), ('기록', 'Noun')], [('쑥쑥', 'Adverb'), ('크는', 'Verb'), ('빅', 'Noun'), ('테크', 'Noun'), ("'", 'Punctuation'), ('경', 'Modifier'), ('고등', 'Noun'), ("'", 'Punctuation'), ('에', 'Josa'), ('...', 'Punctuation'), ('SKT', 'Alpha'), ('-', 'Punctuation'), ('하나', 'Noun'), ('금융', 'Noun'), (',', 'Punctuation'), ('4300억', 'Number'), ('짜리', 'Foreign'), ('혈맹', 'Noun'), ('맺다', 'Verb')], [('SKT', 'Alpha'), ('-', 'Punctuation'), ('하나', 'Noun'), ('금융', 'Noun'), ('MOU', 'Alpha'), ('…', 'Punctuation'), ('통신', 'Noun'), ('+', 'Punctuation'), ('금융', 'Noun'), ('지주', 'Noun'), ('‘', 'Foreign'), ('짝짓기', 'Noun'), ('’,', 'Punctuation'), ('빅', 'Noun'), ('블러시', 'Noun'), ('대', 'Suffix'), ('앞당기나', 'Verb')], [('CJ', 'Alpha'), ('대', 'Modifier'), ('한', 'Modifier'), ('통운', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('로', 'Josa'), ('배송', 'Noun'), ('박스', 'Noun'), ('크기', 'Noun'), ('10%', 'Number'), ('줄여', 'Verb')], [('대', 'Modifier'), ('전시', 'Noun'), (',', 'Punctuation'), ('공직자', 'Noun'), ('대상', 'Noun'), ('데이터', 'Noun'), ('역량', 'Noun'), ('강화', 'Noun'), ('교육', 'Noun')], [('교통', 'Noun'), ('연구원', 'Noun'), (',', 'Punctuation'), ('부동산', 'Noun'), ('분야', 'Noun'), ('빅데이터', 'Noun'), ('플랫폼', 'Noun'), ('·', 'Punctuation'), ('센터', 'Noun'), ('구축', 'Noun')], [('플랜', 'Noun'), ('투', 'Noun'), ('비즈니스', 'Noun'), ('컨설팅', 'Noun'), (',', 'Punctuation'), ('빅데이터', 'Noun'), ('통합', 'Noun'), ('솔루션', 'Noun'), ("'", 'Punctuation'), ('e', 'Alpha'), ('∙', 'F ...
#
#
#
#
# [('빅데이터', 16), ('분석', 5), ('금융', 4), ('택배', 3), ('크기', 3), ('브랜드', 3), ('평판', 3), ('통운', 3), ('박스', 3), ('빅', 3), ('상자', 2), ('필수', 2), ('교통', 2), ('플랫폼', 2), ('구축', 2), ('위', 2), ('배송', 2), ('보증', 2), ('보험', 2), ('경우', 2)]
# {'빅데이터': 16, '분석': 5, '금융': 4, '택배': 3, '크기': 3, '브랜드': 3, '평판': 3, '통운': 3, '박스': 3, '빅': 3, '상자': 2, '필수': 2, '교통': 2, '플랫폼': 2, '구축': 2, '위': 2, '배송': 2, '보증': 2, '보험': 2, '경우': 2}
